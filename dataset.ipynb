# %%
# tra duong dan, ae doi ten "nam1706" thanh ten kaggle roi copy mang xuong cell duoi
import os
print(os.listdir('/kaggle/input/datasets/nam1706/phy-dataset/'))
# Out:
# ['Physics_Problems_Text_Only.csv']

# %%
# Import thư viện
import pandas as pd
pd.set_option('display.max_colwidth', None)

# 2. Hiển thị tất cả các cột (nếu có nhiều cột bị ẩn)
pd.set_option('display.max_columns', None)

# 3. Hiển thị tất cả các dòng (cẩn thận nếu file quá lớn)
pd.set_option('display.max_rows', None)
# Đọc file CSV (thay 'ten_file.csv' bằng tên file thực tế của bạn)
df = pd.read_csv('/kaggle/input/datasets/nam1706/phy-dataset/Physics_Problems_Text_Only.csv')



# Kích thước (dòng, cột)
df.shape
# Danh sách tên cột
df.columns.tolist()
# Thống kê mô tả cho cột số
df.describe()
# Out:
#            id  \
# count    1755
# unique   1755
# top     QA703
# freq        1
#
#                                                                                                                                                                                                                                         question  \
# count                                                                                                                                                                                                                                       1754
# unique                                                                                                                                                                                                                                      1752
# ...

# %%
df.head(200)
# Out:
#         id  \
# 0    TD401
# 1    TD402
# 2    LD001
# 3    LD002
# 4    LD003
# 5    LD004
# 6    LD005
# 7    LD006
# 8    LD007
# 9    LD008
# 10   LD009
# 11   LD010
# 12   LD011
# 13   LD012
# 14   LD013
# 15   LD014
# 16   LD015
# 17   LD016
# 18   LD017
# 19   LD018
# 20   LD019
# 21   LD020
# 22   LD021
# 23   LD022
# 24   LD023
# 25   LD024
# 26   LD025
# 27   LD026
# 28   LD027
# 29   LD028
# 30   LD029
# 31   LD030
# 32   LD031
# 33   LD032
# 34   LD033
# 35   LD034
# 36   LD035
# 37   LD036
# 38   LD037
# 39   LD038
# 40   LD039
# 41   LD040
# 42   LD041
# 43   LD042
# 44   LD043
# 45   LD044
# 46   LD045
# 47   LD046
# 48   LD047
# 49   LD048
# 50   LD049
# 51   LD050
# 52   LD051
# 53   LD052
# 54   LD053
# 55   LD054
# 56   LD055
# 57   LD056
# 58   LD057
# 59   LD058
# 60   LD059
# 61   LD060
# 62   LD061
# 63   LD062
# 64   LD063
# 65   LD064
# 66   LD065
# 67   LD066
# 68   LD067
# 69   LD068
# 70   LD069
# 71   LD070
# 72   LD071
# 73   LD072
# 74   LD073
# ...
